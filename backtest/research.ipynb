# %%
# pip install numpy pandas matplotlib ccxt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ccxt
# Out:
# fatal: bad revision 'HEAD'

# %%
fast_sma_window = 50
slow_sma_window = 200

# ! I just coded the long-only version, but including short is very similar !

# Top 10 Marketcap -> https://coinmarketcap.com/

# Symbol Naming Conventions -> https://github.com/ccxt/ccxt/wiki/Manual#contract-naming-conventions
# BTC/USDT -> spot
# BTC/USDT -> perp USDT
# BTC/USDT:BTC -> perp coin
# BTC/USDC:USDC -> perp USDC

symbols = ["BTC/USDT", "ETH/USDT", "BNB/USDT", "SOL/USDT", "XRP/USDT",
           "AVAX/USDT", "DOGE/USDT", "ADA/USDT", "TRX/USDT", "SHIB/USDT"]

plot_benchmark = True

since = "01/01/2017"
timeframe = "1d"
fee = 0.0001

exchange = ccxt.binance()

# %%
from datetime import datetime

def date_to_milliseconds(date_string):
    date_format = "%d/%m/%Y"
    date = datetime.strptime(date_string, date_format)
    milliseconds = int(date.timestamp() * 1000)
    return milliseconds

since_millis = date_to_milliseconds(since)
print(since, since_millis)
# Out:
# 01/01/2017 1483228800000

# %%
ohlcv_columns = ["timestamp", "open", "high", "low", "close", "volume"]

def fetch_raw_ohlcvs(symbols):
    raw_ohlcvs = {}
    for symbol in symbols:
        price_date = exchange.fetch_ohlcv(symbol, timeframe=timeframe, since=0, params={"paginate": True})
        
        ohlcv = pd.DataFrame(price_date, columns=ohlcv_columns)
        ohlcv["timestamp"] = pd.to_datetime(ohlcv["timestamp"], unit="ms")
        ohlcv = ohlcv.set_index("timestamp")
        
        raw_ohlcvs[symbol] = ohlcv

    return raw_ohlcvs

raw_ohlcvs = fetch_raw_ohlcvs(symbols)
raw_ohlcvs
# Out:
# {'BTC/USDT':                 open      high       low     close        volume
#  timestamp
#  2017-08-17   4261.48   4485.39   4200.74   4285.08    795.150377
#  2017-08-18   4285.08   4371.52   3938.77   4108.37   1199.888264
#  2017-08-19   4108.37   4184.69   3850.00   4139.98    381.309763
#  2017-08-20   4120.98   4211.08   4032.62   4086.29    467.083022
#  2017-08-21   4069.13   4119.62   3911.79   4016.00    691.743060
#  ...              ...       ...       ...       ...           ...
#  2024-06-23  64262.01  64521.00  63178.32  63210.01   8224.454470
#  2024-06-24  63210.01  63369.80  58402.00  60293.30  52161.354140
#  2024-06-25  60293.30  62420.00  60257.06  61806.01  31189.243610
#  2024-06-26  61806.01  62487.81  60712.00  60864.99  22485.664630
#  2024-06-27  60864.98  61455.15  60606.63  61258.48   7815.208270
#
#  [2507 rows x 5 columns],
#  'ETH/USDT':                open     high      low    close        volume
#  timestamp
#  2017-08-17   301.13   312.18   298.00   302.00    7030.71034
#  2017-08-18   302.00   311.79   283.94   293.96    9537.84646
#  2017-08-19   293.31   299.90   278.00   290.91    2146.19773
#  2017-08-20   289.41   300.53   282.85   299.10    2510.13871
#  2017-08-21   299.10   346.52   294.60   323.29    5219.44542
#  ...             ...      ...      ...      ...           ...
#  2024-06-23  3495.76  3521.45  3406.38  3420.91  133411.43040
#  2024-06-24  3420.91  3435.76  3240.00  3352.73  543370.42290
#  2024-06-25  3352.74  3430.88  3336.76  3394.91  240036.22360
#  2024-06-26  3394.91  3426.75  3325.01  3371.44  206949.34180
#  2024-06-27  3371.77  3418.07  3361.74  3413.14   87143.50480
#
#  [2507 rows x 5 columns],
#  'BNB/USDT':                 open      high       low     close      volume
#  timestamp
#  2017-11-06    1.5000    1.7990    0.5000    1.5710  120615.340
#  2017-11-07    1.5710    1.8000    1.5389    1.8000  134129.730
#  2017-11-08    1.7901    1.9900    1.7479    1.9889  347290.260
#  2017-11-09    1.9781    2.1997    1.9000    1.9900  287037.200
#  2017-11-10    1.9900    2.0200    1.6019    1.7133  484658.900
#  ...              ...       ...       ...       ...         ...
#  2024-06-23  591.1000  593.2000  576.0000  577.5000  141025.834
#  2024-06-24  577.5000  582.0000  551.2000  568.1000  356915.248
#  2024-06-25  568.1000  580.0000  566.4000  578.2000  177300.699
#  2024-06-26  578.3000  584.7000  567.4000  573.0000  154770.344
#  2024-06-27  573.1000  576.5000  566.4000  573.2000   93952.769
#
#  [2426 rows x 5 columns],
#  'SOL/USDT':                 open      high       low     close       volume
#  timestamp
#  2020-08-11    2.8500    3.5208    2.8433    3.2985  1552384.780
#  2020-08-12    3.2985    3.9289    3.0800    3.7558  1737042.950
#  2020-08-13    3.7500    4.1387    3.5003    3.7300  1685759.240
#  2020-08-14    3.7207    3.7676    3.3210    3.4099  1474161.790
#  2020-08-15    3.4181    3.7400    3.1500    3.1730  1070233.200
#  ...              ...       ...       ...       ...          ...
#  2024-06-23  133.7000  135.0900  128.2200  128.6900  1492401.231
#  2024-06-24  128.6800  132.6600  122.0000  132.3300  5583497.777
#  2024-06-25  132.3400  139.9000  131.2000  136.5800  3963661.704
#  2024-06-26  136.5700  140.4100  134.8500  136.8100  2503428.066
#  2024-06-27  136.8100  139.6100  135.2000  139.4700  1018773.889
#
#  [1417 rows x 5 columns],
#  'XRP/USDT':                open     high      low    close        volume
#  timestamp
#  2018-05-04  0.50000  1.50000  0.50000  0.88990  2.089021e+07
#  2018-05-05  0.88980  0.93500  0.88800  0.90280  1.681617e+07
#  2018-05-06  0.90280  0.91800  0.83774  0.86483  1.600204e+07
#  2018-05-07  0.86482  0.86886  0.80000  0.82490  1.730349e+07
#  2018-05-08  0.82490  0.84802  0.79200  0.80667  1.297130e+07
#  ...             ...      ...      ...      ...           ...
#  2024-06-23  0.48670  0.48920  0.47420  0.47970  9.509978e+07
#  2024-06-24  0.47980  0.48250  0.46200  0.47400  3.851230e+08
#  2024-06-25  0.47410  0.48020  0.47310  0.47570  2.260457e+08
#  2024-06-26  0.47580  0.47830  0.46520  0.46980  2.434095e+08
#  2024-06-27  0.46970  0.47190  0.46570  0.47080  1.401391e+08
#
#  [2247 rows x 5 columns],
#  'TON/USDT':               open    high     low   close      volume
#  timestamp
#  2024-03-01  2.9950  2.9950  2.6650  2.7120   8899143.2
#  2024-03-02  2.7134  2.7610  2.6267  2.7198   7073631.0
#  2024-03-03  2.7188  2.7454  2.5000  2.6767   6544039.5
#  2024-03-04  2.6767  2.7876  2.6443  2.7328   6753343.3
#  2024-03-05  2.7333  2.7629  2.1612  2.5951   9542320.2
#  ...            ...     ...     ...     ...         ...
#  2024-06-23  7.3380  7.7447  7.3209  7.4988  27448198.1
#  2024-06-24  7.4988  7.6107  7.0100  7.4932  31517829.9
#  2024-06-25  7.4933  7.7291  7.4330  7.4892  17774582.6
#  2024-06-26  7.4887  7.6798  7.3636  7.6312  13217614.6
#  2024-06-27  7.6303  7.7862  7.5600  7.7520   6989882.2
#
#  [119 rows x 5 columns],
#  'DOGE/USDT':                 open      high       low     close        volume
#  timestamp
#  2019-07-05  0.004490  0.004600  0.003550  0.003870  1.928298e+09
#  2019-07-06  0.003874  0.003943  0.003365  0.003500  1.010744e+09
#  2019-07-07  0.003504  0.003650  0.003400  0.003538  5.306140e+08
#  2019-07-08  0.003538  0.003562  0.003400  0.003458  3.084457e+08
#  2019-07-09  0.003462  0.003582  0.003356  0.003455  2.533756e+08
#  ...              ...       ...       ...       ...           ...
#  2024-06-23  0.123760  0.126400  0.120900  0.122220  5.066058e+08
#  2024-06-24  0.122220  0.123950  0.113540  0.119020  1.238017e+09
#  2024-06-25  0.119010  0.128620  0.118820  0.126150  9.045000e+08
#  2024-06-26  0.126160  0.128650  0.121800  0.122760  5.694774e+08
#  2024-06-27  0.122770  0.123970  0.120610  0.122420  2.606406e+08
#
#  [1820 rows x 5 columns],
#  'ADA/USDT':                open     high      low    close        volume
#  timestamp
#  2018-04-17  0.25551  0.28800  0.23983  0.24260  6.746229e+07
#  2018-04-18  0.24260  0.26460  0.24201  0.26200  3.132810e+07
#  2018-04-19  0.26199  0.27500  0.25777  0.27004  5.085998e+07
#  2018-04-20  0.27004  0.30442  0.26648  0.30108  7.108428e+07
#  2018-04-21  0.30161  0.30700  0.26509  0.28668  9.271984e+07
#  ...             ...      ...      ...      ...           ...
#  2024-06-23  0.38470  0.39340  0.37850  0.38000  5.659383e+07
#  2024-06-24  0.38010  0.38170  0.36100  0.37770  1.193407e+08
#  2024-06-25  0.37770  0.39740  0.37690  0.39180  7.010434e+07
#  2024-06-26  0.39180  0.39650  0.38240  0.38500  8.031172e+07
#  2024-06-27  0.38500  0.38600  0.37770  0.38040  3.389035e+07
#
#  [2264 rows x 5 columns],
#  'TRX/USDT':                open     high      low    close       volume
#  timestamp
#  2018-06-11  0.05000  0.05000  0.04258  0.04840   72569508.9
#  2018-06-12  0.04837  0.04849  0.04081  0.04330  189962494.5
#  2018-06-13  0.04332  0.04476  0.03726  0.04098  468993557.7
#  2018-06-14  0.04093  0.04574  0.03992  0.04505  488364234.2
#  2018-06-15  0.04506  0.04592  0.04149  0.04232  406097492.9
#  ...             ...      ...      ...      ...          ...
#  2024-06-23  0.11967  0.12050  0.11909  0.11924  148497951.4
#  2024-06-24  0.11924  0.11992  0.11772  0.11909  331140116.7
#  2024-06-25  0.11909  0.12218  0.11908  0.12189  233319740.6
#  2024-06-26  0.12190  0.12500  0.12182  0.12268  304171429.4
#  2024-06-27  0.12267  0.12349  0.12264  0.12305   87324786.1
#
#  [2209 rows x 5 columns],
#  'SHIB/USDT':                 open      high       low     close        volume
#  timestamp
#  2021-05-10  0.000014  0.000050  0.000014  0.000035  9.530231e+13
#  2021-05-11  0.000035  0.000038  0.000028  0.000030  6.451279e+13
#  2021-05-12  0.000030  0.000031  0.000018  0.000018  8.690914e+13
#  2021-05-13  0.000018  0.000024  0.000015  0.000021  9.125488e+13
#  2021-05-14  0.000021  0.000022  0.000018  0.000018  4.092785e+13
#  ...              ...       ...       ...       ...           ...
#  2024-06-23  0.000018  0.000018  0.000017  0.000018  1.099343e+12
#  2024-06-24  0.000018  0.000018  0.000016  0.000017  3.213688e+12
#  2024-06-25  0.000017  0.000018  0.000017  0.000018  3.032135e+12
#  2024-06-26  0.000018  0.000018  0.000017  0.000017  1.811843e+12
#  2024-06-27  0.000017  0.000017  0.000017  0.000017  8.295759e+11
#
#  [1145 rows x 5 columns]}

# %%
raw_ohlcvs["BTC/USDT"]
# Out:
#                 open      high       low     close        volume
# timestamp
# 2017-08-17   4261.48   4485.39   4200.74   4285.08    795.150377
# 2017-08-18   4285.08   4371.52   3938.77   4108.37   1199.888264
# 2017-08-19   4108.37   4184.69   3850.00   4139.98    381.309763
# 2017-08-20   4120.98   4211.08   4032.62   4086.29    467.083022
# 2017-08-21   4069.13   4119.62   3911.79   4016.00    691.743060
# ...              ...       ...       ...       ...           ...
# 2024-06-23  64262.01  64521.00  63178.32  63210.01   8224.454470
# 2024-06-24  63210.01  63369.80  58402.00  60293.30  52161.354140
# 2024-06-25  60293.30  62420.00  60257.06  61806.01  31189.243610
# 2024-06-26  61806.01  62487.81  60712.00  60864.99  22485.664630
# 2024-06-27  60864.98  61455.15  60606.63  61258.48   7815.208270
#
# [2507 rows x 5 columns]

# %%
def calc_features(ohlcvs):
    for symbol, ohlcv in ohlcvs.items():
        fast_sma = ohlcv['close'].rolling(window=fast_sma_window).mean()
        slow_sma = ohlcv['close'].rolling(window=slow_sma_window).mean()

        ohlcvs[symbol]["sma_cross_up"] = np.where((fast_sma > slow_sma) & (fast_sma.shift(1) < slow_sma.shift(1)), True, False)
        ohlcvs[symbol]["sma_cross_down"] = np.where((fast_sma < slow_sma) & (fast_sma.shift(1) > slow_sma.shift(1)), True, False) # slow crosses over fast sma

        ohlcvs[symbol]["fast_sma"] = fast_sma
        ohlcvs[symbol]["slow_sma"] = slow_sma

        # We add a in_position column to keep track of the position
        ohlcvs[symbol]["in_position"] = False

    return ohlcvs

ohlcvs = calc_features(raw_ohlcvs)
ohlcvs
# Out:
# {'BTC/USDT':                 open      high       low     close        volume  \
#  timestamp
#  2017-08-17   4261.48   4485.39   4200.74   4285.08    795.150377
#  2017-08-18   4285.08   4371.52   3938.77   4108.37   1199.888264
#  2017-08-19   4108.37   4184.69   3850.00   4139.98    381.309763
#  2017-08-20   4120.98   4211.08   4032.62   4086.29    467.083022
#  2017-08-21   4069.13   4119.62   3911.79   4016.00    691.743060
#  ...              ...       ...       ...       ...           ...
#  2024-06-23  64262.01  64521.00  63178.32  63210.01   8224.454470
#  2024-06-24  63210.01  63369.80  58402.00  60293.30  52161.354140
#  2024-06-25  60293.30  62420.00  60257.06  61806.01  31189.243610
#  2024-06-26  61806.01  62487.81  60712.00  60864.99  22485.664630
#  2024-06-27  60864.98  61455.15  60606.63  61258.48   7815.208270
#
#              sma_cross_up  sma_cross_down    fast_sma     slow_sma  in_position
#  timestamp
#  2017-08-17         False           False         NaN          NaN        False
#  2017-08-18         False           False         NaN          NaN        False
#  2017-08-19         False           False         NaN          NaN        False
#  2017-08-20         False           False         NaN          NaN        False
#  2017-08-21         False           False         NaN          NaN        False
#  ...                  ...             ...         ...          ...          ...
#  2024-06-23         False           False  66571.5814  57470.97945        False
#  2024-06-24         False           False  66497.2074  57556.08025        False
#  2024-06-25         False           False  66470.0238  57644.25535        False
#  2024-06-26         False           False  66441.0820  57730.01230        False
#  2024-06-27         False           False  66442.3910  57817.35715        False
#
#  [2507 rows x 10 columns],
#  'ETH/USDT':                open     high      low    close        volume  sma_cross_up  \
#  timestamp
#  2017-08-17   301.13   312.18   298.00   302.00    7030.71034         False
#  2017-08-18   302.00   311.79   283.94   293.96    9537.84646         False
#  2017-08-19   293.31   299.90   278.00   290.91    2146.19773         False
#  2017-08-20   289.41   300.53   282.85   299.10    2510.13871         False
#  2017-08-21   299.10   346.52   294.60   323.29    5219.44542         False
#  ...             ...      ...      ...      ...           ...           ...
#  2024-06-23  3495.76  3521.45  3406.38  3420.91  133411.43040         False
#  2024-06-24  3420.91  3435.76  3240.00  3352.73  543370.42290         False
#  2024-06-25  3352.74  3430.88  3336.76  3394.91  240036.22360         False
#  2024-06-26  3394.91  3426.75  3325.01  3371.44  206949.34180         False
#  2024-06-27  3371.77  3418.07  3361.74  3413.14   87143.50480         False
#
#              sma_cross_down   fast_sma    slow_sma  in_position
#  timestamp
#  2017-08-17           False        NaN         NaN        False
#  2017-08-18           False        NaN         NaN        False
#  2017-08-19           False        NaN         NaN        False
#  2017-08-20           False        NaN         NaN        False
#  2017-08-21           False        NaN         NaN        False
#  ...                    ...        ...         ...          ...
#  2024-06-23           False  3472.9898  3029.07640        False
#  2024-06-24           False  3477.3162  3034.06140        False
#  2024-06-25           False  3483.9624  3039.24235        False
#  2024-06-26           False  3491.2774  3044.39710        False
#  2024-06-27           False  3500.0560  3049.70085        False
#
#  [2507 rows x 10 columns],
#  'BNB/USDT':                 open      high       low     close      volume  sma_cross_up  \
#  timestamp
#  2017-11-06    1.5000    1.7990    0.5000    1.5710  120615.340         False
#  2017-11-07    1.5710    1.8000    1.5389    1.8000  134129.730         False
#  2017-11-08    1.7901    1.9900    1.7479    1.9889  347290.260         False
#  2017-11-09    1.9781    2.1997    1.9000    1.9900  287037.200         False
#  2017-11-10    1.9900    2.0200    1.6019    1.7133  484658.900         False
#  ...              ...       ...       ...       ...         ...           ...
#  2024-06-23  591.1000  593.2000  576.0000  577.5000  141025.834         False
#  2024-06-24  577.5000  582.0000  551.2000  568.1000  356915.248         False
#  2024-06-25  568.1000  580.0000  566.4000  578.2000  177300.699         False
#  2024-06-26  578.3000  584.7000  567.4000  573.0000  154770.344         False
#  2024-06-27  573.1000  576.5000  566.4000  573.2000   93952.769         False
#
#              sma_cross_down  fast_sma  slow_sma  in_position
#  timestamp
#  2017-11-06           False       NaN       NaN        False
#  2017-11-07           False       NaN       NaN        False
#  2017-11-08           False       NaN       NaN        False
#  2017-11-09           False       NaN       NaN        False
#  2017-11-10           False       NaN       NaN        False
#  ...                    ...       ...       ...          ...
#  2024-06-23           False   607.098  464.0295        False
#  2024-06-24           False   606.620  465.7070        False
#  2024-06-25           False   606.420  467.4035        False
#  2024-06-26           False   606.350  469.0800        False
#  2024-06-27           False   606.042  470.7470        False
#
#  [2426 rows x 10 columns],
#  'SOL/USDT':                 open      high       low     close       volume  sma_cross_up  \
#  timestamp
#  2020-08-11    2.8500    3.5208    2.8433    3.2985  1552384.780         False
#  2020-08-12    3.2985    3.9289    3.0800    3.7558  1737042.950         False
#  2020-08-13    3.7500    4.1387    3.5003    3.7300  1685759.240         False
#  2020-08-14    3.7207    3.7676    3.3210    3.4099  1474161.790         False
#  2020-08-15    3.4181    3.7400    3.1500    3.1730  1070233.200         False
#  ...              ...       ...       ...       ...          ...           ...
#  2024-06-23  133.7000  135.0900  128.2200  128.6900  1492401.231         False
#  2024-06-24  128.6800  132.6600  122.0000  132.3300  5583497.777         False
#  2024-06-25  132.3400  139.9000  131.2000  136.5800  3963661.704         False
#  2024-06-26  136.5700  140.4100  134.8500  136.8100  2503428.066         False
#  2024-06-27  136.8100  139.6100  135.2000  139.4700  1018773.889         False
#
#              sma_cross_down  fast_sma   slow_sma  in_position
#  timestamp
#  2020-08-11           False       NaN        NaN        False
#  2020-08-12           False       NaN        NaN        False
#  2020-08-13           False       NaN        NaN        False
#  2020-08-14           False       NaN        NaN        False
#  2020-08-15           False       NaN        NaN        False
#  ...                    ...       ...        ...          ...
#  2024-06-23           False  156.8438  132.67095        False
#  2024-06-24           False  156.5758  132.99390        False
#  2024-06-25           False  156.2510  133.30210        False
#  2024-06-26           False  156.0266  133.62465        False
#  2024-06-27           False  155.9724  133.94765        False
#
#  [1417 rows x 10 columns],
#  'XRP/USDT':                open     high      low    close        volume  sma_cross_up  \
#  timestamp
#  2018-05-04  0.50000  1.50000  0.50000  0.88990  2.089021e+07         False
#  2018-05-05  0.88980  0.93500  0.88800  0.90280  1.681617e+07         False
#  2018-05-06  0.90280  0.91800  0.83774  0.86483  1.600204e+07         False
#  2018-05-07  0.86482  0.86886  0.80000  0.82490  1.730349e+07         False
#  2018-05-08  0.82490  0.84802  0.79200  0.80667  1.297130e+07         False
#  ...             ...      ...      ...      ...           ...           ...
#  2024-06-23  0.48670  0.48920  0.47420  0.47970  9.509978e+07         False
#  2024-06-24  0.47980  0.48250  0.46200  0.47400  3.851230e+08         False
#  2024-06-25  0.47410  0.48020  0.47310  0.47570  2.260457e+08         False
#  2024-06-26  0.47580  0.47830  0.46520  0.46980  2.434095e+08         False
#  2024-06-27  0.46970  0.47190  0.46570  0.47080  1.401391e+08         False
#
#              sma_cross_down  fast_sma  slow_sma  in_position
#  timestamp
#  2018-05-04           False       NaN       NaN        False
#  2018-05-05           False       NaN       NaN        False
#  2018-05-06           False       NaN       NaN        False
#  2018-05-07           False       NaN       NaN        False
#  2018-05-08           False       NaN       NaN        False
#  ...                    ...       ...       ...          ...
#  2024-06-23           False  0.510830  0.561044        False
#  2024-06-24           False  0.509718  0.560198        False
#  2024-06-25           False  0.508428  0.559216        False
#  2024-06-26           False  0.507334  0.558273        False
#  2024-06-27           False  0.506408  0.557318        False
#
#  [2247 rows x 10 columns],
#  'TON/USDT':               open    high     low   close      volume  sma_cross_up  \
#  timestamp
#  2024-03-01  2.9950  2.9950  2.6650  2.7120   8899143.2         False
#  2024-03-02  2.7134  2.7610  2.6267  2.7198   7073631.0         False
#  2024-03-03  2.7188  2.7454  2.5000  2.6767   6544039.5         False
#  2024-03-04  2.6767  2.7876  2.6443  2.7328   6753343.3         False
#  2024-03-05  2.7333  2.7629  2.1612  2.5951   9542320.2         False
#  ...            ...     ...     ...     ...         ...           ...
#  2024-06-23  7.3380  7.7447  7.3209  7.4988  27448198.1         False
#  2024-06-24  7.4988  7.6107  7.0100  7.4932  31517829.9         False
#  2024-06-25  7.4933  7.7291  7.4330  7.4892  17774582.6         False
#  2024-06-26  7.4887  7.6798  7.3636  7.6312  13217614.6         False
#  2024-06-27  7.6303  7.7862  7.5600  7.7520   6989882.2         False
#
#              sma_cross_down  fast_sma  slow_sma  in_position
#  timestamp
#  2024-03-01           False       NaN       NaN        False
#  2024-03-02           False       NaN       NaN        False
#  2024-03-03           False       NaN       NaN        False
#  2024-03-04           False       NaN       NaN        False
#  2024-03-05           False       NaN       NaN        False
#  ...                    ...       ...       ...          ...
#  2024-06-23           False  6.831502       NaN        False
#  2024-06-24           False  6.861998       NaN        False
#  2024-06-25           False  6.896198       NaN        False
#  2024-06-26           False  6.935836       NaN        False
#  2024-06-27           False  6.975690       NaN        False
#
#  [119 rows x 10 columns],
#  'DOGE/USDT':                 open      high       low     close        volume  \
#  timestamp
#  2019-07-05  0.004490  0.004600  0.003550  0.003870  1.928298e+09
#  2019-07-06  0.003874  0.003943  0.003365  0.003500  1.010744e+09
#  2019-07-07  0.003504  0.003650  0.003400  0.003538  5.306140e+08
#  2019-07-08  0.003538  0.003562  0.003400  0.003458  3.084457e+08
#  2019-07-09  0.003462  0.003582  0.003356  0.003455  2.533756e+08
#  ...              ...       ...       ...       ...           ...
#  2024-06-23  0.123760  0.126400  0.120900  0.122220  5.066058e+08
#  2024-06-24  0.122220  0.123950  0.113540  0.119020  1.238017e+09
#  2024-06-25  0.119010  0.128620  0.118820  0.126150  9.045000e+08
#  2024-06-26  0.126160  0.128650  0.121800  0.122760  5.694774e+08
#  2024-06-27  0.122770  0.123970  0.120610  0.122420  2.606406e+08
#
#              sma_cross_up  sma_cross_down  fast_sma  slow_sma  in_position
#  timestamp
#  2019-07-05         False           False       NaN       NaN        False
#  2019-07-06         False           False       NaN       NaN        False
#  2019-07-07         False           False       NaN       NaN        False
#  2019-07-08         False           False       NaN       NaN        False
#  2019-07-09         False           False       NaN       NaN        False
#  ...                  ...             ...       ...       ...          ...
#  2024-06-23         False           False  0.149580  0.128286        False
#  2024-06-24         False           False  0.148741  0.128401        False
#  2024-06-25         False           False  0.148135  0.128524        False
#  2024-06-26         False           False  0.147590  0.128645        False
#  2024-06-27         False           False  0.147174  0.128748        False
#
#  [1820 rows x 10 columns],
#  'ADA/USDT':                open     high      low    close        volume  sma_cross_up  \
#  timestamp
#  2018-04-17  0.25551  0.28800  0.23983  0.24260  6.746229e+07         False
#  2018-04-18  0.24260  0.26460  0.24201  0.26200  3.132810e+07         False
#  2018-04-19  0.26199  0.27500  0.25777  0.27004  5.085998e+07         False
#  2018-04-20  0.27004  0.30442  0.26648  0.30108  7.108428e+07         False
#  2018-04-21  0.30161  0.30700  0.26509  0.28668  9.271984e+07         False
#  ...             ...      ...      ...      ...           ...           ...
#  2024-06-23  0.38470  0.39340  0.37850  0.38000  5.659383e+07         False
#  2024-06-24  0.38010  0.38170  0.36100  0.37770  1.193407e+08         False
#  2024-06-25  0.37770  0.39740  0.37690  0.39180  7.010434e+07         False
#  2024-06-26  0.39180  0.39650  0.38240  0.38500  8.031172e+07         False
#  2024-06-27  0.38500  0.38600  0.37770  0.38040  3.389035e+07         False
#
#              sma_cross_down  fast_sma  slow_sma  in_position
#  timestamp
#  2018-04-17           False       NaN       NaN        False
#  2018-04-18           False       NaN       NaN        False
#  2018-04-19           False       NaN       NaN        False
#  2018-04-20           False       NaN       NaN        False
#  2018-04-21           False       NaN       NaN        False
#  ...                    ...       ...       ...          ...
#  2024-06-23           False  0.442454  0.542541        False
#  2024-06-24           False  0.440848  0.542152        False
#  2024-06-25           False  0.439602  0.541384        False
#  2024-06-26           False  0.438474  0.540413        False
#  2024-06-27           False  0.437046  0.539341        False
#
#  [2264 rows x 10 columns],
#  'TRX/USDT':                open     high      low    close       volume  sma_cross_up  \
#  timestamp
#  2018-06-11  0.05000  0.05000  0.04258  0.04840   72569508.9         False
#  2018-06-12  0.04837  0.04849  0.04081  0.04330  189962494.5         False
#  2018-06-13  0.04332  0.04476  0.03726  0.04098  468993557.7         False
#  2018-06-14  0.04093  0.04574  0.03992  0.04505  488364234.2         False
#  2018-06-15  0.04506  0.04592  0.04149  0.04232  406097492.9         False
#  ...             ...      ...      ...      ...          ...           ...
#  2024-06-23  0.11967  0.12050  0.11909  0.11924  148497951.4         False
#  2024-06-24  0.11924  0.11992  0.11772  0.11909  331140116.7         False
#  2024-06-25  0.11909  0.12218  0.11908  0.12189  233319740.6         False
#  2024-06-26  0.12190  0.12500  0.12182  0.12268  304171429.4         False
#  2024-06-27  0.12267  0.12349  0.12264  0.12305   87324786.1         False
#
#              sma_cross_down  fast_sma  slow_sma  in_position
#  timestamp
#  2018-06-11           False       NaN       NaN        False
#  2018-06-12           False       NaN       NaN        False
#  2018-06-13           False       NaN       NaN        False
#  2018-06-14           False       NaN       NaN        False
#  2018-06-15           False       NaN       NaN        False
#  ...                    ...       ...       ...          ...
#  2024-06-23           False  0.118298  0.118040        False
#  2024-06-24           False  0.118258  0.118115        False
#  2024-06-25           False  0.118323  0.118191        False
#  2024-06-26           False  0.118367  0.118271        False
#  2024-06-27           False  0.118369  0.118347        False
#
#  [2209 rows x 10 columns],
#  'SHIB/USDT':                 open      high       low     close        volume  \
#  timestamp
#  2021-05-10  0.000014  0.000050  0.000014  0.000035  9.530231e+13
#  2021-05-11  0.000035  0.000038  0.000028  0.000030  6.451279e+13
#  2021-05-12  0.000030  0.000031  0.000018  0.000018  8.690914e+13
#  2021-05-13  0.000018  0.000024  0.000015  0.000021  9.125488e+13
#  2021-05-14  0.000021  0.000022  0.000018  0.000018  4.092785e+13
#  ...              ...       ...       ...       ...           ...
#  2024-06-23  0.000018  0.000018  0.000017  0.000018  1.099343e+12
#  2024-06-24  0.000018  0.000018  0.000016  0.000017  3.213688e+12
#  2024-06-25  0.000017  0.000018  0.000017  0.000018  3.032135e+12
#  2024-06-26  0.000018  0.000018  0.000017  0.000017  1.811843e+12
#  2024-06-27  0.000017  0.000017  0.000017  0.000017  8.295759e+11
#
#              sma_cross_up  sma_cross_down  fast_sma  slow_sma  in_position
#  timestamp
#  2021-05-10         False           False       NaN       NaN        False
#  2021-05-11         False           False       NaN       NaN        False
#  2021-05-12         False           False       NaN       NaN        False
#  2021-05-13         False           False       NaN       NaN        False
#  2021-05-14         False           False       NaN       NaN        False
#  ...                  ...             ...       ...       ...          ...
#  2024-06-23         False           False  0.000023  0.000019        False
#  2024-06-24         False           False  0.000023  0.000019        False
#  2024-06-25         False           False  0.000023  0.000019        False
#  2024-06-26         False           False  0.000023  0.000019        False
#  2024-06-27         False           False  0.000023  0.000019        False
#
#  [1145 rows x 10 columns]}

# %%
ohlcv_btc = ohlcvs["BTC/USDT"]

ohlcv_btc["sma_cross_up"][ohlcv_btc["sma_cross_up"] == True]
# Out:
# timestamp
# 2019-04-24    True
# 2020-02-18    True
# 2020-05-21    True
# 2021-09-15    True
# 2023-02-07    True
# 2023-10-30    True
# Name: sma_cross_up, dtype: bool

# %%
ohlcv_btc["sma_cross_down"][ohlcv_btc["sma_cross_down"] == True]
# Out:
# timestamp
# 2018-03-31    True
# 2019-10-26    True
# 2020-03-25    True
# 2021-06-19    True
# 2022-01-14    True
# 2023-09-12    True
# Name: sma_cross_down, dtype: bool

# %%
def backtest():
    ohlcv = ohlcv_btc.dropna()

    open_position = {}
    closed_trades = []

    for index, row in ohlcv.iterrows():
        if row["sma_cross_up"] and not open_position:
            open_position = {
                "entry_date": index,
                "entry_price": row["close"],
                "fee": fee
            }

            ohlcv.at[index, "in_position"] = True

        elif row["sma_cross_down"] and open_position:
            open_position["exit_date"] = index
            open_position["exit_price"] = row["close"]
            open_position["fee"] += fee

            open_position["pnl"] = open_position["exit_price"] / open_position["entry_price"] - 1 - open_position["fee"]

            closed_trades.append(open_position)
            open_position = {}

            # Set "in_position" to True for the current row and False for the next row
            ohlcv.at[index, "in_position"] = True
            current_loc = ohlcv.index.get_loc(index)
            if current_loc < len(ohlcv) - 1:
                next_index = ohlcv.index[current_loc + 1]
                ohlcv.at[next_index, "in_position"] = False

        else:
            ohlcv.at[index, "in_position"] = bool(open_position)

    return closed_trades, ohlcv["in_position"]

closed_trades, in_position_array = backtest()

# %%
in_position_array
# Out:
# timestamp
# 2018-03-04    False
# 2018-03-05    False
# 2018-03-06    False
# 2018-03-07    False
# 2018-03-08    False
#               ...
# 2024-06-23     True
# 2024-06-24     True
# 2024-06-25     True
# 2024-06-26     True
# 2024-06-27     True
# Name: in_position, Length: 2308, dtype: bool

# %%
closed_trades_df = pd.DataFrame(closed_trades)
closed_trades_df
# Out:
#   entry_date  entry_price     fee  exit_date  exit_price       pnl
# 0 2019-04-24      5415.00  0.0002 2019-10-26     9230.00  0.704324
# 1 2020-02-18     10164.71  0.0002 2020-03-25     6677.43 -0.343277
# 2 2020-05-21      9068.65  0.0002 2021-06-19    35483.72  2.912590
# 3 2021-09-15     48121.41  0.0002 2022-01-14    43059.96 -0.105381
# 4 2023-02-07     23240.46  0.0002 2023-09-12    25840.10  0.111658

# %%
realised_returns = closed_trades_df[["exit_date", "pnl"]]
realised_returns = realised_returns.set_index("exit_date")
realised_returns["comp_pnl"] = (realised_returns["pnl"] + 1).cumprod() - 1

realised_returns
# Out:
#                  pnl  comp_pnl
# exit_date
# 2019-10-26  0.704324  0.704324
# 2020-03-25 -0.343277  0.119269
# 2021-06-19  2.912590  3.379239
# 2022-01-14 -0.105381  2.917752
# 2023-09-12  0.111658  3.355201

# %%
unrealised_returns = pd.concat([ohlcv_btc["close"], in_position_array], axis=1)
unrealised_returns["pct_change"] = unrealised_returns["close"].pct_change()
unrealised_returns = unrealised_returns.dropna()
unrealised_returns["pnl"] = np.where(unrealised_returns["in_position"], unrealised_returns["pct_change"], 0)
unrealised_returns["comp_pnl"] = (unrealised_returns["pnl"] + 1).cumprod() - 1
unrealised_returns
# Out:
#                close in_position  pct_change       pnl  comp_pnl
# timestamp
# 2018-03-04  11515.00       False    0.004407  0.000000  0.000000
# 2018-03-05  11454.00       False   -0.005297  0.000000  0.000000
# 2018-03-06  10716.48       False   -0.064390  0.000000  0.000000
# 2018-03-07   9910.00       False   -0.075256  0.000000  0.000000
# 2018-03-08   9271.64       False   -0.064416  0.000000  0.000000
# ...              ...         ...         ...       ...       ...
# 2024-06-23  63210.01        True   -0.016370 -0.016370  7.191837
# 2024-06-24  60293.30        True   -0.046143 -0.046143  6.813840
# 2024-06-25  61806.01        True    0.025089  0.025089  7.009883
# 2024-06-26  60864.99        True   -0.015225 -0.015225  6.887929
# 2024-06-27  61258.48        True    0.006465  0.006465  6.938924
#
# [2308 rows x 5 columns]

# %%
def calculate_DD(returns):
    """
    Calculates various drawdown metrics, such as maximum drawdown, maximum drawdown duration, date of maximum drawdown, average drawdown and drawdown array
    based on the provided returns.
    """
    returns = returns.dropna()

    cum_returns = returns.cumsum()

    highwatermark = np.zeros(cum_returns.shape)
    drawdown = np.zeros(cum_returns.shape)
    drawdown_duration = np.zeros(cum_returns.shape)
    
    for t in np.arange(1, len(cum_returns)):
        highwatermark[t] = np.maximum(highwatermark[t-1], cum_returns.iloc[t])
        drawdown[t] = (1 + cum_returns.iloc[t]) / (1 + highwatermark[t]) - 1
        
        if drawdown[t] == 0:
            drawdown_duration[t] = 0
        else:
            drawdown_duration[t] = drawdown_duration[t-1] + 1

    maxDD = np.min(drawdown)
    avgDD = np.mean(drawdown)
    i = np.argmin(drawdown)
    maxDDD = np.max(drawdown_duration)
    
    return maxDD, maxDDD, avgDD, returns.index[i], drawdown

# %%
def show_stats(returns: pd.DataFrame, cum_returns: pd.DataFrame) -> dict:
    """
    Computes and displays various trading statistics, such as average trade returns, win rate, PnL, drawdowns,
    and other performance metrics, based on the provided returns.
    """
    maxDD, maxDDD, avgDD, maxDD_date, _ = calculate_DD(returns)

    stats = {
        "Avg Trade Return": returns.mean(),
        "Avg Positive Trade Return": returns[returns >= 0].mean(),
        "Avg Negative Trade Return": returns[returns < 0].mean(),
        "Win Rate": len(returns[returns >= 0]) / len(returns),
        "PnL (%)": cum_returns.iloc[-1] * 100,
        "Max Drawdown": maxDD,
        "Max Drawdown Duration": maxDDD,
        "Max Drawdown Date": maxDD_date,
        "Avg Drawdown": avgDD
    }
    
    return stats

show_stats(unrealised_returns["pnl"], unrealised_returns["comp_pnl"])
# Out:
# {'Avg Trade Return': np.float64(0.0012626225536023054),
#  'Avg Positive Trade Return': np.float64(0.009334043064860645),
#  'Avg Negative Trade Return': np.float64(-0.022674270577723973),
#  'Win Rate': 0.7478336221837089,
#  'PnL (%)': np.float64(693.8924409302484),
#  'Max Drawdown': np.float64(-0.4256287436080851),
#  'Max Drawdown Duration': np.float64(999.0),
#  'Max Drawdown Date': Timestamp('2020-03-12 00:00:00'),
#  'Avg Drawdown': np.float64(-0.08432781362397404)}

# %%
def plot_returns(returns: pd.DataFrame, comp_returns: pd.DataFrame):
    """
    Plots the equity curve, underwater drawdown, and benchmark (if applicable) for the given returns.
    """
    _, _, _, _, drawdown = calculate_DD(returns)

    start_date = comp_returns.index[0]

    if plot_benchmark:
        benchmark_pnl = ohlcv_btc["close"].pct_change()
        benchmark_pnl = benchmark_pnl[start_date:]
        benchmark_comp_pnl = (benchmark_pnl + 1).cumprod() - 1
        benchmark_percentages = benchmark_comp_pnl * 100
    
    cum_returns_percentages = comp_returns * 100
    drawdown_percentages = drawdown * 100
    
    plt.figure(figsize=(14, 7))

    # Equity curve
    plt.subplot(2, 1, 1)
    plt.plot(cum_returns_percentages, label="Equity Curve", color="b")
    if plot_benchmark:
        plt.plot(benchmark_percentages, label="Benchmark (BTC)", color="y")
    plt.title("Equity Curve")
    plt.xlabel("Date")
    plt.ylabel("Cumulative Returns (%)")
    plt.legend()
    plt.grid(True)

    # Drawdown
    plt.subplot(2, 1, 2)
    plt.fill_between(cum_returns_percentages.index, 0, drawdown_percentages, color="red", alpha=0.3)
    plt.title("Underwater Drawdown Plot")
    plt.xlabel("Date")
    plt.ylabel("Drawdown Percentage (%)")
    plt.grid(True)

    plt.suptitle(f"Golden Cross Strategy", fontsize=16)
    
    plt.tight_layout()
    plt.show()

plot_returns(unrealised_returns["pnl"], unrealised_returns["comp_pnl"])

# %%
# export closed_trades & compare with TradingView
closed_trades_df.to_csv("closed_trades.csv")
